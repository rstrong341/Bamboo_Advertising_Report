# %%
# %matplotlib inline
import pandas as pd; pd.set_option('display.max_columns', None)
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("data/ad.csv")

# %%
df.columns
# Out:
# Index(['Start Date', 'End Date', 'Campaign Name', 'Ad Group Name', 'Targeting',
#        'Match Type', 'Customer Search Term', 'Impressions', 'Clicks',
#        'Click-Thru Rate (CTR)', 'Cost Per Click (CPC)', '7 Day Total Sales ',
#        'Spend', 'Total Advertising Cost of Sales (ACoS) ',
#        'Total Return on Advertising Spend (RoAS)', 'Number of Days', 'Key',
#        'Impressions Per Day', 'Spend Per Day', 'Sales Per Day'],
#       dtype='object')

# %%
#Top search terms to reasess
zero = df.loc[df['Total Advertising Cost of Sales (ACoS) '] == '0']
zero
zero_df = zero.sort_values(by='Spend', ascending=False).head(10)
zero_df
# Out:
#     Start Date   End Date        Campaign Name   Ad Group Name  \
# 376  26-May-21  19-Jun-21      Floral - Manual  Exact Ad Group
# 328   5-Jun-21  19-Jun-21        Floral - ASIN            ASIN
# 357  27-May-21  17-Jun-21      Floral - Manual  Exact Ad Group
# 270  25-May-21  12-Jun-21  Rainforest - Manual  Exact Ad Group
# 342  25-May-21  16-Jun-21        Floral - ASIN            ASIN
# 314  27-May-21  17-Jun-21        Floral - ASIN            ASIN
# 257  26-May-21  12-Jun-21    Rainforest - ASIN            ASIN
# 163  25-May-21  27-May-21  Rainforest - Manual  Broad Ad Group
# 520  28-May-21   8-Jun-21      Floral - Manual  Exact Ad Group
# 229  25-May-21  11-Jun-21    Rainforest - ASIN            ASIN
#
#                  Targeting Match Type        Customer Search Term  \
# 376  bamboo toddler plates      EXACT       bamboo toddler plates
# 328      asin="B08F2PR7JS"          -                  b08f2pr7js
# 357        plates for kids      EXACT             plates for kids
# 270        plates for kids      EXACT             plates for kids
# 342      asin="B07KYWP2MT"          -                  b07kywp2mt
# 314      asin="B01MG7OE9X"          -                  b01mg7oe9x
# 257      asin="B07DD9WBZW"          -                  b07dd9wbzw
# 163  kids plates and bowls      BROAD  kids plates and bowls sets
# 520          toddler bowls      EXACT               toddler bowls
# 229      asin="B07KYWP2MT"          -                  b07kywp2mt
#
#      Impressions  Clicks Click-Thru Rate (CTR)  Cost Per Click (CPC)  \
# 376          757      33                 4.36%                  2.15
# 328         5157      40                 0.78%                  0.76
# 357          713      17                 2.38%                  1.73
# 270          664      15                 2.26%                  1.83
# 342         3552      24                 0.68%                  0.98
# 314         2136      28                 1.31%                  0.82
# 257         1011      18                 1.78%                  1.12
# 163         4271      15                 0.35%                  1.31
# 520          675      11                 1.63%                  1.76
# 229         3495      21                 0.60%                  0.84
#
#      7 Day Total Sales   Spend Total Advertising Cost of Sales (ACoS)   \
# 376                 0.0  70.82                                       0
# 328                 0.0  30.31                                       0
# 357                 0.0  29.47                                       0
# 270                 0.0  27.42                                       0
# 342                 0.0  23.48                                       0
# 314                 0.0  23.08                                       0
# 257                 0.0  20.19                                       0
# 163                 0.0  19.69                                       0
# 520                 0.0  19.40                                       0
# 229                 0.0  17.57                                       0
#
#      Total Return on Advertising Spend (RoAS)  Number of Days  \
# 376                                       0.0              24
# 328                                       0.0              14
# 357                                       0.0              21
# 270                                       0.0              18
# 342                                       0.0              22
# 314                                       0.0              21
# 257                                       0.0              17
# 163                                       0.0               2
# 520                                       0.0              11
# 229                                       0.0              17
#
#                                                    Key  Impressions Per Day  \
# 376  bamboo toddler plates Floral - Manual Exact Ad...            31.541667
# 328    b08f2pr7js Floral - ASIN ASIN asin="B08F2PR7JS"           368.357143
# 357  plates for kids Floral - Manual Exact Ad Group...            33.952381
# 270  plates for kids Rainforest - Manual Exact Ad G...            36.888889
# 342    b07kywp2mt Floral - ASIN ASIN asin="B07KYWP2MT"           161.454545
# 314    b01mg7oe9x Floral - ASIN ASIN asin="B01MG7OE9X"           101.714286
# 257  b07dd9wbzw Rainforest - ASIN ASIN asin="B07DD9...            59.470588
# 163  kids plates and bowls sets Rainforest - Manual...          2135.500000
# 520  toddler bowls Floral - Manual Exact Ad Group t...            61.363636
# 229  b07kywp2mt Rainforest - ASIN ASIN asin="B07KYW...           205.588235
#
#      Spend Per Day  Sales Per Day
# 376       2.950833            0.0
# 328       2.165000            0.0
# 357       1.403333            0.0
# 270       1.523333            0.0
# 342       1.067273            0.0
# 314       1.099048            0.0
# 257       1.187647            0.0
# 163       9.845000            0.0
# 520       1.763636            0.0
# 229       1.033529            0.0

# %%
ax = zero_df.plot.bar(x='Customer Search Term', y='Spend', rot=90)
ax.set_xlabel("Customer Search Term", fontsize=12)
ax.set_ylabel("Spend(Dollars)", fontsize=12)
ax.set_title("Highest Spending With Zero Sales", fontsize=16, fontweight="bold")
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.regplot(df['Spend'], df['7 Day Total Sales '])
# Out:
# C:\Users\rstro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Spend', ylabel='7 Day Total Sales '>

# %%
plt.figure(figsize=(12, 10))
sns.regplot(df['Spend Per Day'], df['Sales Per Day'])
# Out:
# C:\Users\rstro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Spend Per Day', ylabel='Sales Per Day'>

# %%
plt.figure(figsize=(12, 10))
sns.regplot(df['Spend Per Day'], df['Impressions Per Day'])
# Out:
# C:\Users\rstro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Spend Per Day', ylabel='Impressions Per Day'>

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df['Spend Per Day'],df['Impressions Per Day'])
ax = sns.regplot(x='Spend Per Day', y = 'Impressions Per Day', data = df, color='Purple',
                line_kws={'label':"y={0:1f}x+{1:1f}".format(slope,intercept)})
ax.legend()

plt.show()

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df['Spend Per Day'],df['Sales Per Day'])
ax = sns.regplot(x='Spend Per Day', y = 'Sales Per Day', data = df, color='Blue',
                line_kws={'label':"y={0:1f}x+{1:1f}".format(slope,intercept)})
ax.legend()

plt.show()

# %%
res = stats.linregress(df['Spend Per Day'],df['Impressions Per Day'])
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.476277

# %%
plt.plot(df['Spend Per Day'],df['Sales Per Day'], 'o', label='original data')
plt.plot(df['Spend Per Day'], res.intercept + res.slope*df['Spend Per Day'], 'r', label='fitted line')
plt.legend()
plt.show()

# %%
X=df['Spend Per Day']
Y=df['Impressions Per Day']
X
# Out:
# 0      1.150000
# 1      1.667778
# 2      2.470000
# 3      1.980000
# 4      1.610000
#          ...
# 561    0.040000
# 562    0.150000
# 563    0.038750
# 564    0.240000
# 565    0.060000
# Name: Spend Per Day, Length: 566, dtype: float64

# %%
from scipy.stats import linregress
X = df['Spend Per Day'].values
Y = df['Impressions Per Day'].values
linregress(X, Y)
# Out:
# LinregressResult(slope=52.19001690889847, intercept=-21.34037993187095, rvalue=0.690128525471058, pvalue=2.971074298704403e-81, stderr=2.304456805038864)

# %%
corr = df.loc[df['Campaign Name'] == 'Floral - Manual'].corr()[['Spend Per Day']]
corr = corr.sort_values(by='Spend Per Day', ascending=False)
plt.figure(figsize=(15, 10))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Out:
#                                           Spend Per Day
# Impressions                                    0.722681
# Clicks                                         0.930605
# Cost Per Click (CPC)                           0.352592
# 7 Day Total Sales                              0.790059
# Spend                                          0.957426
# Total Return on Advertising Spend (RoAS)      -0.001775
# Number of Days                                 0.329643
# Impressions Per Day                            0.712823
# Spend Per Day                                  1.000000
# Sales Per Day                                  0.423361

# %%
corr = df_copy.loc[df_copy['Pos'] == 'TE'].corr()[['FantasyPoints/Gm']]
plt.figure(figsize=(15, 10))
sns.heatmap(corr, annot=True)
