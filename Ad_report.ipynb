# %%
import pandas as pd

# %%
df = pd.read_csv("data/search_cleaned.csv")
df.head(5)
# Out:
#   Start Date   End Date        Campaign Name   Ad Group Name  \
# 0  29-May-21  29-May-21  Rainforest - Manual  Broad Ad Group
# 1  31-May-21   9-Jun-21  Rainforest - Manual  Broad Ad Group
# 2  26-May-21  26-May-21  Rainforest - Manual  Broad Ad Group
# 3  29-May-21  29-May-21  Rainforest - Manual  Broad Ad Group
# 4  11-Jun-21  11-Jun-21  Rainforest - Manual  Broad Ad Group
#
#             Targeting Match Type  \
# 0  bamboo kids plates      BROAD
# 1  bamboo kids plates      BROAD
# 2  bamboo kids plates      BROAD
# 3  bamboo kids plates      BROAD
# 4  bamboo kids plates      BROAD
#
#                             Customer Search Term  Impressions  Clicks  \
# 0                          bamboo kids plate set            2       1
# 1               bamboo kids plates and bowl sets          222      10
# 2                          bamboo plate set kids            7       1
# 3  grow forward kids bamboo plates and bowl sets            8       1
# ...

# %%
df['Key'] = df['Customer Search Term'] + ' ' + df['Campaign Name']+ ' ' + df['Ad Group Name']+ ' ' + df['Targeting']

# %%
df['Number of Days'].replace({0: 1}, inplace=True)

# %%
df.columns
# Out:
# Index(['Start Date', 'End Date', 'Campaign Name', 'Ad Group Name', 'Targeting',
#        'Match Type', 'Customer Search Term', 'Impressions', 'Clicks',
#        'Click-Thru Rate (CTR)', 'Cost Per Click (CPC)', '7 Day Total Sales ',
#        'Spend', 'Total Advertising Cost of Sales (ACoS) ',
#        'Total Return on Advertising Spend (RoAS)', 'Number of Days', 'Key'],
#       dtype='object')

# %%
df.replace('-', 0)
# Out:
#     Start Date   End Date        Campaign Name   Ad Group Name  \
# 0    29-May-21  29-May-21  Rainforest - Manual  Broad Ad Group
# 1    31-May-21   9-Jun-21  Rainforest - Manual  Broad Ad Group
# 2    26-May-21  26-May-21  Rainforest - Manual  Broad Ad Group
# 3    29-May-21  29-May-21  Rainforest - Manual  Broad Ad Group
# 4    11-Jun-21  11-Jun-21  Rainforest - Manual  Broad Ad Group
# ..         ...        ...                  ...             ...
# 561  19-Jun-21  19-Jun-21    Floral - Ultimate        Ultimate
# 562   3-Jun-21   3-Jun-21    Floral - Ultimate        Ultimate
# 563  30-May-21  15-Jun-21    Floral - Ultimate        Ultimate
# 564   3-Jun-21   3-Jun-21    Floral - Ultimate        Ultimate
# 565   9-Jun-21   9-Jun-21    Floral - Ultimate        Ultimate
#
#               Targeting Match Type  \
# 0    bamboo kids plates      BROAD
# 1    bamboo kids plates      BROAD
# 2    bamboo kids plates      BROAD
# 3    bamboo kids plates      BROAD
# ...

# %%
df['Impressions Per Day'] = df['Impressions']/df['Number of Days']
df['Spend Per Day'] = df['Spend']/df['Number of Days']
df['Sales Per Day'] = df['7 Day Total Sales ']/df['Number of Days']
df
# Out:
#     Start Date   End Date        Campaign Name   Ad Group Name  \
# 0    29-May-21  29-May-21  Rainforest - Manual  Broad Ad Group
# 1    31-May-21   9-Jun-21  Rainforest - Manual  Broad Ad Group
# 2    26-May-21  26-May-21  Rainforest - Manual  Broad Ad Group
# 3    29-May-21  29-May-21  Rainforest - Manual  Broad Ad Group
# 4    11-Jun-21  11-Jun-21  Rainforest - Manual  Broad Ad Group
# ..         ...        ...                  ...             ...
# 561  19-Jun-21  19-Jun-21    Floral - Ultimate        Ultimate
# 562   3-Jun-21   3-Jun-21    Floral - Ultimate        Ultimate
# 563  30-May-21  15-Jun-21    Floral - Ultimate        Ultimate
# 564   3-Jun-21   3-Jun-21    Floral - Ultimate        Ultimate
# 565   9-Jun-21   9-Jun-21    Floral - Ultimate        Ultimate
#
#               Targeting Match Type  \
# 0    bamboo kids plates      BROAD
# 1    bamboo kids plates      BROAD
# 2    bamboo kids plates      BROAD
# 3    bamboo kids plates      BROAD
# ...

# %%
sort_df = df.sort_values(by='Sales Per Day', ascending=False).head(10)

# %%
sort_df
# Out:
#     Start Date   End Date          Campaign Name   Ad Group Name  \
# 400   1-Jun-21   1-Jun-21        Floral - Manual  Broad Ad Group
# 265  25-May-21  12-Jun-21    Rainforest - Manual  Exact Ad Group
# 275  25-May-21  12-Jun-21    Rainforest - Manual  Exact Ad Group
# 352  25-May-21  19-Jun-21        Floral - Manual  Exact Ad Group
# 462  13-Jun-21  14-Jun-21        Floral - Manual  Broad Ad Group
# 435  14-Jun-21  14-Jun-21        Floral - Manual  Broad Ad Group
# 547   1-Jun-21   3-Jun-21  Rainforest - Ultimate        Ultimate
# 304  18-Jun-21  18-Jun-21          Floral - ASIN            ASIN
# 206  26-May-21  12-Jun-21      Rainforest - ASIN            ASIN
# 362  25-May-21  19-Jun-21        Floral - Manual  Exact Ad Group
#
#                   Targeting Match Type            Customer Search Term  \
# 400             kids plates      BROAD          kids dinner plates eco
# 265  bamboo plates for kids      EXACT          bamboo plates for kids
# ...

# %%
df['Total Advertising Cost of Sales (ACoS) '] = df['Total Advertising Cost of Sales (ACoS) '].fillna(0)

# %%
#Top search terms to reasess
Zero = df.loc[df['Total Advertising Cost of Sales (ACoS) '] == 0]
Zero

# %%
zero_df = Zero.sort_values(by='Spend', ascending=False).head(10)
zero_df

# %%
df.to_csv(r'data\ad.csv', index = False)
